# %%
import matplotlib.pyplot as pyplot
# %config InlineBackend.figure_format = "retina"

import TransferMatrixMethod as tmm
import RefractiveIndexDB as ridb
import PlotTools as plt

# %%
simul_0 = tmm.TMMOptics()
simul_0, simul_0.__dict__
# Out:
# (<TMMOOPapproach.TMMOptics at 0x12a9befd0>, {})

# %%
simul_0.beam_parameters(range(200, 1001))
simul_0.__dict__.keys()
# Out:
# dict_keys(['wavelength', 'angle_inc_deg', 'angle_inc_rad', 'polarisation'])

# %%
l1 = tmm.LayerTMMO(ridb.air(simul_0.wavelength))
l2 = tmm.LayerTMMO(ridb.silicon(simul_0.wavelength), thickness=200.0)
l3 = tmm.LayerTMMO(ridb.BK7(simul_0.wavelength))
layers = [l1, l2, l3]

# %%
simul_0.tmm_spectra(layers)

# %%
simul_0.__dict__.keys()
# Out:
# dict_keys(['wavelength', 'angle_inc_deg', 'angle_inc_rad', 'polarisation', 'wavelength_0', 'n_wavelength_0', 'physical_thickness', 'ref_coeff_p', 'ref_coeff_s', 'tra_coeff_p', 'tra_coeff_s', 'transmittance_p', 'transmittance_s', 'reflectance_p', 'reflectance_s', 'reflectance', 'transmittance', 'admittance_p', 'admittance_s', 'phase'])

# %%
plt.plot_spectrum_1d(simul_0.wavelength, simul_0.reflectance_p)
plt.plot_spectrum_1d(simul_0.wavelength, simul_0.transmittance_p, ylabel="Transmittance")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Transmittance'>)

# %%
plt.plot_index_profile(simul_0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Thickness profile [nm]', ylabel='Refractive index at lambda_0'>)

# %%
simul_0.tmm_emf(layers)

# %%
plt.plot_spectrum_2d(simul_0.wavelength, simul_0.layers_depth, simul_0.EMFp[:, 0, :].T)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Angle of incidence [degree]'>,
#  <matplotlib.collections.QuadMesh at 0x12ac58a90>)
