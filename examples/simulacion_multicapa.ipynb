# %%
import numpy
import importlib
# %config InlineBackend.figure_format = "retina"

import TransferMatrixMethod as tmm
import RefractiveIndexDB as ridb
import PlotTools as plt

# %%
simul_0 = tmm.TMMOptics()
simul_0, simul_0.__dict__
# Out:
# (<TMMOOPapproach.TMMOptics at 0x104086d60>, {})

# %%
simul_0.beam_parameters(range(200, 1001), wavelength_0=700)
simul_0.__dict__.keys()
# Out:
# dict_keys(['wavelength', 'angle_inc_deg', 'angle_inc_rad', 'polarisation', 'wavelength_0', 'wavelength_0_idx'])

# %%
l1 = tmm.LayerTMMO(ridb.air(simul_0.wavelength))
l2 = tmm.LayerTMMO(1.45*numpy.ones(len(simul_0.wavelength)), thickness=1/4, layer_type="OT")
l3 = tmm.LayerTMMO(3.45*numpy.ones(len(simul_0.wavelength)), thickness=1/4, layer_type="OT")
layers = [l1, l2, l3, l2, l3, l2, l3, l2, l3, l1]

# %%
simul_0.tmm_spectra(layers)

# %%
plt.plot_spectrum_1d(simul_0.wavelength, simul_0.reflectance)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Reflectance'>)

# %%
simul_0.tmm_emf(layers)

# %%
plt.plot_spectrum_2d(simul_0.wavelength, simul_0.layers_depth, numpy.log10((simul_0.EMFs[:, 0, :].T)), title_label="EMF", ylabel="Depth [nm]")
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Depth [nm]'>,
#  <matplotlib.collections.QuadMesh at 0x105781670>)

# %%
plt.plot_index_profile(simul_0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Thickness profile [nm]', ylabel='Refractive index at lambda_0'>)

# %%
plt.plot_index_profile(simul_0, plotemf=True, angle=0, wavelength=700)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Thickness profile [nm]', ylabel='Refractive index at lambda_0'>)

# %%
plt.plot_index_profile(simul_0, plotemf=True)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Thickness profile [nm]', ylabel='Refractive index at lambda_0'>)

# %%
simul_0.photonic_dispersion(layers)
# Out:
# /Users/kwazii/Leandro/code_dev__/python/ajuste_capas_simples/TMMOOPapproach.py:416: RuntimeWarning: invalid value encountered in arccos
#   kpr[b, a] = numpy.arccos(_bloch_wavevector(a1, a2, fpr[a]))
# /Users/kwazii/Leandro/code_dev__/python/ajuste_capas_simples/TMMOOPapproach.py:417: RuntimeWarning: invalid value encountered in arccos
#   ksr[b, a] = numpy.arccos(_bloch_wavevector(a1, a2, fsr[a]))

# %%
plt.pbg_dispersion_1d(simul_0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='K*Lambda/pi', ylabel='omega*Lambda/(2*pi)'>)

# %%
plt.pbg_dispersion_1d_alt(simul_0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='K*Lambda/pi', ylabel='omega*Lambda/(2*pi)'>)

# %%
plt.pbg_dispersion_1d_imre(simul_0)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='K*Lambda/pi', ylabel='omega*Lambda/(2*pi)'>)

# %%
simul_0.tmm_spectra_emf(layers)

# %%
plt.plot_spectrum_1d(simul_0.wavelength, simul_0.reflectance_p)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Reflectance'>)

# %%
plt.plot_spectrum_2d(simul_0.wavelength, simul_0.layers_depth, simul_0.EMFp[:, 0, :].T)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <AxesSubplot:xlabel='Wavelength [nm]', ylabel='Angle of incidence [degree]'>,
#  <matplotlib.collections.QuadMesh at 0x119b71550>)
